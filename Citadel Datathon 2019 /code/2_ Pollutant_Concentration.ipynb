# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams.update({"font.size":20})

# %% [markdown]
# # Read data

# %%
concentration = pd.read_csv("../Datasets/air_concentrations.csv")

# %%
concentration.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84900 entries, 0 to 84899
# Data columns (total 20 columns):
# latitude       84900 non-null float64
# longitude      84900 non-null float64
# state_code     84900 non-null object
# county         82783 non-null object
# date_on        84900 non-null object
# date_off       84900 non-null object
# TSO4           82378 non-null float64
# TNH4           82377 non-null float64
# CA             82296 non-null float64
# MG             82298 non-null float64
# NA             82294 non-null float64
# K              82210 non-null float64
# CL             67363 non-null float64
# NSO4           82388 non-null float64
# NHNO3          82388 non-null float64
# WSO2           82378 non-null float64
# WNO3           8920 non-null float64
# total_SO2      82369 non-null float64
# total_NO3      82380 non-null float64
# flow_volume    82861 non-null float64
# dtypes: float64(16), object(4)
# memory usage: 13.0+ MB

# %%
concentration.head()
# Out:
#     latitude  longitude state_code    county              date_on  \
# 0  39.988309 -79.251573         PA  Somerset  01/03/2000 16:37:00
# 1  39.988309 -79.251573         PA  Somerset  01/10/2000 16:09:00
# 2  39.988309 -79.251573         PA  Somerset  01/17/2000 20:07:00
# 3  39.988309 -79.251573         PA  Somerset  01/24/2000 21:11:00
# 4  39.988309 -79.251573         PA  Somerset  01/31/2000 16:40:00
#
#               date_off    TSO4    TNH4      CA      MG      NA       K  CL  \
# 0  01/10/2000 16:03:00  2.3406  0.7764  0.1267  0.0144  0.1740  0.0536 NaN
# 1  01/17/2000 19:57:00  1.7681  0.9436  0.2127  0.0272  0.1700  0.0452 NaN
# 2  01/24/2000 21:00:00  3.7462  0.9171  0.1410  0.0220  0.1805  0.0534 NaN
# 3  01/31/2000 16:33:00  3.6490  1.4580  0.1359  0.0217  0.3100  0.0534 NaN
# 4  02/07/2000 16:06:00  3.8717  0.8672  0.0944  0.0146  0.1143  0.0391 NaN
#
#      NSO4   NHNO3     WSO2    WNO3  total_SO2  total_NO3  flow_volume
# 0  0.4753  1.1347  10.2084  0.5588    10.5254     1.8930      14.9233
# 1  1.2391  1.3881  16.4770  0.4621    17.3035     2.3097      14.9819
# 2  1.5380  3.2918  31.8606  0.8644    32.8865     4.1565      14.5267
# 3  1.9024  3.1171  26.0389  1.0820    27.3078     4.5255      13.8887
# 4  2.3108  4.8706  28.7423  0.7741    30.2836     5.6604      14.6524

# %%
def to_year(x):
    try:
        return int(x[6:10])
    except:
        return None

# %%
concentration["year"] = concentration["date_on"].apply(to_year)

# %%
polltants = concentration.columns[6:19].values
polltants
# Out:
# array(['TSO4', 'TNH4', 'CA', 'MG', 'NA', 'K', 'CL', 'NSO4', 'NHNO3',
#        'WSO2', 'WNO3', 'total_SO2', 'total_NO3'], dtype=object)

# %%
c_each_state = concentration.groupby(["state_code", "year"])[polltants].sum().reset_index()

# %%
c_each_state["latitude"] = concentration.groupby(["state_code", "year"])["latitude"].mean().values
c_each_state["longitude"] = concentration.groupby(["state_code", "year"])["longitude"].mean().values

# %%
# county level
c_each_county = concentration.groupby(["state_code","county", "year"])[polltants].sum().reset_index()

# %%
c_each_county["latitude"] = concentration.groupby(["state_code","county", "year"])["latitude"].mean().values

# %%
c_each_county["longitude"] = concentration.groupby(["state_code","county", "year"])["longitude"].mean().values

# %%
c_each_county.to_csv("../AggregatedData/pollutant_concentration_by_county_year.csv")

# %% [markdown]
# # write to csv

# %%
c_each_state.to_csv("../AggregatedData/pollutant_concentration_by_state_year.csv", index=False)

# %%
c_each_state.head()
# Out:
#   state_code  year     TSO4    TNH4      CA      MG      NA       K      CL  \
# 0         AK  2000  30.6402  7.2945  1.3514  0.6791  3.1649  2.4077     NaN
# 1         AK  2001  34.8446  6.5909  2.3623  0.6915  3.2312  0.8495     NaN
# 2         AK  2002  36.8374  7.9195  3.2205  0.9789  3.4978  1.8826     NaN
# 3         AK  2003  34.5709  5.5223  2.5747  0.9612  3.2455  1.3031  1.9649
# 4         AK  2004  22.8321  8.5270  3.6536  0.9303  2.5129  2.3108  2.8712
#
#       NSO4    NHNO3     WSO2    WNO3  total_SO2  total_NO3
# 0   7.2252   8.1895  28.2964  9.4383    33.1156    15.3540
# 1   4.8928   8.5161  35.2390  8.2529    38.5015    14.9714
# 2  13.2493  13.9284  31.0982  1.3480    39.9362    21.6260
# 3  12.4985  10.5177  30.8192     NaN    39.1557    15.8725
# 4   9.6423   7.5887  18.3086     NaN    24.7405    15.9951

# %%
top_10_SO2_state = c_each_state.groupby("state_code")["total_SO2"].sum().sort_values(ascending=False).index[:10]
top_10_NO3_state = c_each_state.groupby("state_code")["total_NO3"].sum().sort_values(ascending=False).index[:10]
top_10_MG_state = c_each_state.groupby("state_code")["MG"].sum().sort_values(ascending=False).index[:10]

# %%
top_10_SO2_state
# Out:
# Index([u'PA', u'OH', u'KY', u'VA', u'IN', u'IL', u'MD', u'TN', u'HI', u'MI'], dtype='object', name=u'state_code')

# %%
top_10_NO3_state
# Out:
# Index([u'OH', u'KY', u'PA', u'CA', u'IL', u'MI', u'IN', u'NC', u'ON', u'TN'], dtype='object', name=u'state_code')

# %%
'Texas', u'Indiana', u'Ohio', u'Illinois', u'Kentucky',
       u'West Virginia', u'Pennsylvania', u'North Carolina', u'Florida',
       u'Missouri

# %%
plt.figure(figsize=(15,10))
for state in top_10_NO3_state:
    c_s = c_each_state[c_each_state["state_code"] == state]
    plt.plot(c_s["year"], c_s["total_NO3"], label=state)
plt.legend()
plt.xlabel("year")
plt.xticks(range(2000, 2019, 2))
plt.ylabel("NO$_3$ $\mu g/m$")
plt.title("Top 10 NO$_3$ concentration states")
plt.savefig("../plots/NO3_vs_time.png", dpi=200)

# %%
plt.figure(figsize=(15,10))
for state in top_10_SO2_state:
    c_s = c_each_state[c_each_state["state_code"] == state]
    plt.plot(c_s["year"], c_s["total_SO2"], label=state)
plt.legend()
plt.xlabel("year")
plt.xticks(range(2000, 2019, 2))
plt.ylabel("SO$_2$ $\mu g/m$")
plt.title("Top 10 SO$_2$ concentration states")
plt.savefig("../plots/SO2_vs_time.png", dpi=200)

# %%
plt.figure(figsize=(15,10))
for state in top_10_MG_state:
    c_s = c_each_state[c_each_state["state_code"] == state]
    plt.plot(c_s["year"], c_s["MG"], label=state)
plt.legend()
plt.xlabel("year")
plt.xticks(range(2000, 2019, 2))
plt.ylabel("Mercury $\mu g/m$")
plt.title("Top 10 Mercury concentration states")
plt.savefig("../plots/MG_vs_time.png", dpi=200)

# %% [markdown]
# # heatmap

# %%
import shapefile
class World(object):
	"""docstring for Country"""
	def __init__(self):
		self.world = shapefile.Reader('world_admin_2008/world_admin_2008')
		shape = self.world.shapes()
		records = self.world.records()
		self._D = {}
		for i in range(len(shape)):
			cntry = records[i][6]
			self._D.setdefault(cntry, []).append(shape[i])
		self.ALL_COUNTRIES = self._D.keys()


	def __getitem__(self, key):
		if key not in self._D:	raise Exception(cntry + " not valid!!!")
		return self._D[key]

# %%
world = World()

# %%
shape_states = ["MN", "MT", "ND", "", "ID", "WA", "AZ", "CA", "CO", "NV", "NM", "OR", "UT", "WY", "AR", "IA", "KS",
               "MO", "NE", "OK", "SD", "LA", "TX","", "CT", "MA", "NH", "RI", "VT", "AL", "FL","GA", "MS", "SC", "IL",
               "IN", "KY", "NC", "OH", "TN", "VA", "WI", "WV", "DE", "", "MD", "NJ", "NY", "PA", "ME", "MI", ""]

# %%
state_to_shape = {s:i for i, s in enumerate(shape_states)}

# %%
c_each_state.head()
# Out:
#   state_code  year     TSO4    TNH4      CA      MG      NA       K      CL  \
# 0         AK  2000  30.6402  7.2945  1.3514  0.6791  3.1649  2.4077     NaN
# 1         AK  2001  34.8446  6.5909  2.3623  0.6915  3.2312  0.8495     NaN
# 2         AK  2002  36.8374  7.9195  3.2205  0.9789  3.4978  1.8826     NaN
# 3         AK  2003  34.5709  5.5223  2.5747  0.9612  3.2455  1.3031  1.9649
# 4         AK  2004  22.8321  8.5270  3.6536  0.9303  2.5129  2.3108  2.8712
#
#       NSO4    NHNO3     WSO2    WNO3  total_SO2  total_NO3   latitude
# 0   7.2252   8.1895  28.2964  9.4383    33.1156    15.3540  64.385283
# 1   4.8928   8.5161  35.2390  8.2529    38.5015    14.9714  64.427270
# 2  13.2493  13.9284  31.0982  1.3480    39.9362    21.6260  64.427141
# 3  12.4985  10.5177  30.8192     NaN    39.1557    15.8725  64.420500
# 4   9.6423   7.5887  18.3086     NaN    24.7405    15.9951  64.549544

# %%
c_so2_state.sort_values(by="total_SO2", ascending=False)
# Out:
#     state_code  year      TSO4      TNH4        CA       MG        NA  \
# 751         WY  2018  140.2019   83.2173   58.8327   7.5654    9.1816
# 568         PA  2018  252.7174  131.7019   38.2010   6.6009   19.0150
# 253         KY  2018  256.6586  142.4072   45.6292   7.6971   18.1626
# 513         OH  2018  167.4823  114.8829   32.8896   7.0983   11.2644
# 94          CA  2018  158.8756  153.6240   53.5428  13.1787   56.8406
# 198         IL  2018  146.1252  184.2036   60.7330  11.6795   10.3506
# 217         IN  2018  113.6463  115.3043   51.2883   6.2110    7.8106
# 622         TX  2018  177.2583   79.5295   70.0561   8.1208   33.4424
# 310         MI  2018  116.7874  117.8500   31.7424   6.9436    7.2874
# 386         NC  2018  194.8185   83.4118   20.8859   9.9487   60.2222
# 494         NY  2018  145.0390   74.0241   21.3841   4.2750   11.9260
# 272         MD  2018   93.0362   66.2315   12.0328   4.3281   25.7546
# 660         VA  2018  123.1802   50.1240   15.5908   3.5918   12.2525
# 151         FL  2018  182.4948  110.9572   39.0106  25.1616  190.4187
# 732         WV  2018   97.0365   25.9647   17.1753   2.3281    4.9460
# 291         ME  2018   66.8128   31.4414    7.5047   3.5468   21.0523
# 603         TN  2018  108.7838   39.4734   20.4807   3.9972    9.5650
# 234         KS  2018   92.2384  104.9840  129.2026   4.3201    6.8348
# 549         ON  2018   37.6260   44.5521   15.5186   2.2495    3.1475
# 75          AZ  2018   62.4117   35.8846   32.2286   4.0691   11.9408
# 456         NJ  2018   46.7918   40.0713    6.5899   2.2361   13.0352
# 405         ND  2018   31.2652   22.9424   12.1205   2.1045    1.8176
# 113         CO  2018   58.6119   33.5351   25.7886   3.6610    6.0681
# 329         MN  2018   45.9734   38.7250   17.4501   4.3653    3.7311
# 641         UT  2018   35.6076   26.5568   27.8871   3.6467    4.9506
# 530         OK  2018   54.2688   35.4709   15.7250   2.1041    7.4783
# 56          AR  2018   56.7942   16.8782    7.5972   1.8471    7.5451
# 37          AL  2018   49.5179   30.5227    9.7144   1.8591    6.5625
# 132         CT  2018   34.2947   28.9987    4.0522   1.8084   11.9061
# 348         MS  2018   51.4680   17.3671    7.2737   1.7935    7.2196
# 170         GA  2018   44.3363   19.3580    5.1439   1.7344    8.9197
# 713         WI  2018   30.0201   40.6524   11.3061   2.2804    2.6061
# 418         NE  2018   33.8575   47.4160   16.8731   2.3796    1.7028
# 584         SD  2018   22.5637   14.7195   14.4373   1.4149    1.0475
# 437         NH  2018   22.3177    8.7083    2.1952   0.6501    3.2757
# 680         VT  2018   21.6055   15.1383    3.9572   0.7749    2.8171
# 18          AK  2018    9.7542    2.2939    0.9924   0.4505    1.8328
# 367         MT  2018   15.3147    7.8712    7.1243   1.4721    1.2197
# 475         NV  2018   16.3839    8.3151   14.7198   1.6375    3.8992
# 179         ID  2018   11.0398    5.2199    2.8303   0.6422    1.3754
#
#            K        CL     NSO4     NHNO3      WSO2  WNO3  total_SO2  \
# 751  13.4695    5.9001  31.3091  116.6889  140.6141   NaN   161.4980
# 568  13.9450   14.5705  67.7257  140.7290   91.2889   NaN   136.4617
# 253  16.1401    8.0897  59.9749  164.7602   76.1875   NaN   116.1912
# 513  10.0456    8.6824  52.8674  114.9384   70.1023   NaN   105.3645
# 94   21.9515   35.5921  23.3135  168.5306   83.9093   NaN    99.4590
# 198  10.0743    9.1546  43.0867   99.9935   54.5148   NaN    83.2532
# 217   7.2290    6.3855  34.9121   73.3448   56.5120   NaN    79.7984
# 622  11.1224   17.8288  21.1812   73.1063   61.5330   NaN    75.6602
# 310   8.8405    7.4956  36.8471   81.5433   45.6382   NaN    70.2152
# 386  15.0693   60.1090  32.3584   98.6759   46.7672   NaN    68.3498
# 494   8.3782    8.8247  29.5743   80.4508   40.0599   NaN    59.7858
# 272   5.7818   17.8196  20.7210   61.8171   44.8704   NaN    58.6913
# 660   7.6460    6.3422  27.4588   68.3841   34.2201   NaN    52.5346
# 151  14.5906  280.8666  21.1864   31.8490   38.1836   NaN    52.3141
# 732   6.9427    3.9549  18.1096   35.7054   23.8364   NaN    35.9153
# 291   6.8307   18.5191  17.9339   26.5621   22.1698   NaN    34.1312
# 603   7.4090    3.2619  16.2327   68.1491   22.7480   NaN    33.5754
# 234   6.9151    3.9955  10.8531   53.1267   25.8146   NaN    33.0541
# 549   2.2123    3.3733  14.4612   24.9225   16.4967   NaN    26.1420
# 75    4.9871    6.1177   5.9451   61.7639   20.7155   NaN    24.6808
# 456   3.1887   10.2569  10.4519   39.6810   17.6119   NaN    24.5830
# 405   1.8648    0.8197   7.8876   20.8735   18.4062   NaN    23.6675
# 113   6.0430    3.1270   6.4108   57.1071   18.8464   NaN    23.1217
# 329   3.9900    3.2871   8.5044   24.5581   15.6249   NaN    21.2969
# 641   4.5402    2.6234   3.9086   41.6353   17.9356   NaN    20.5432
# 530   3.9303    2.9613   9.6416   29.8578   12.6284   NaN    19.0592
# 56    3.8649    2.1044   9.4123   25.2310   12.6337   NaN    18.9115
# 37    3.9474    3.1417  10.3265   31.0537   11.9224   NaN    18.8099
# 132   2.7313    8.7599   8.3050   26.2984   11.3577   NaN    16.8968
# 348   3.7737    2.8910   7.9267   21.0749   10.8222   NaN    16.1093
# 170   3.9085    4.2244   7.7957   27.0911   10.7971   NaN    15.9974
# 713   2.7046    3.1046   7.3839   18.8099   10.3244   NaN    15.2498
# 418   2.8419    1.5231   4.9635   21.8774   11.1775   NaN    14.4882
# 584   1.8476    0.6787   3.6612   19.8896    9.9519   NaN    12.3941
# 437   1.9317    2.8559   4.1691    8.7300    6.5863   NaN     9.3676
# 680   1.2348    1.9542   3.9818   11.8939    6.4458   NaN     9.1020
# 18    0.6663    2.1554   2.6095    2.1173    6.0221   NaN     7.7628
# 367   2.6387    0.8365   2.7161   11.5362    4.7434   NaN     6.5546
# 475   1.7562    3.1839   1.7162   13.7612    4.6524   NaN     5.7974
# 179   2.3117    0.7649   2.2460   10.2382    4.2116   NaN     5.7099
#
#      total_NO3   latitude   longitude
# 751   198.0510  43.802794 -107.210029
# 568   270.1949  40.745690  -78.673558
# 253   304.5478  37.448607  -85.439125
# 513   227.9947  39.703765  -83.106144
# 94    319.4744  37.059103 -119.531524
# 198   282.6073  40.294607  -89.293414
# 217   187.4836  39.766208  -86.583892
# 622   151.4730  31.635519  -99.879193
# 310   198.0969  43.435285  -84.347484
# 386   180.5185  35.464420  -80.367636
# 494   153.1964  43.272159  -74.833594
# 272   127.0655  38.758444  -76.490670
# 660   117.4196  37.675397  -79.088374
# 151   142.2999  27.784084  -82.029469
# 732    61.1027  38.984969  -80.254709
# 291    57.5803  45.397968  -68.467125
# 603   106.5379  36.051641  -84.400662
# 234   157.2669  39.469081  -96.145022
# 549    69.0784  44.231071  -79.783115
# 75     96.6675  34.296852 -110.488373
# 456    79.1212  40.312303  -74.872663
# 405    43.4836  46.894844 -103.377719
# 113    89.7325  39.189307 -106.631090
# 329    62.8927  48.134931  -93.844012
# 641    67.5301  39.447812 -109.562930
# 530    64.8544  35.750786  -94.669789
# 56     41.7082  34.179278  -93.098755
# 37     61.0827  34.289001  -85.970065
# 132    54.8793  41.840460  -72.010368
# 348    38.1062  34.002747  -89.799183
# 170    46.0186  33.181173  -84.410054
# 713    59.1631  45.206525  -90.597209
# 418    68.9452  42.829154  -97.854128
# 584    34.2923  43.557639 -103.483856
# 437    17.2996  43.944519  -71.700787
# 680    26.8433  44.528300  -72.868800
# 18      4.3776  63.723200 -148.967600
# 367    19.2237  48.510301 -113.996807
# 475    21.8571  39.005121 -114.215932
# 179    15.2953  46.275600 -116.021600

# %%
plt.figure(figsize=(15,10))
yr = 2012
c_so2_state = c_each_state.loc[c_each_state["year"] == yr]
for shape in world['United States']:
    x = [p[0] for p in shape.points]
    y = [p[1] for p in shape.points]
    plt.plot(x,y, c='k')


for i in range(c_so2_state.shape[0]):
    if c_so2_state.state_code.iloc[i] not in ["AK", "HI", "ON"]:
        plt.text(c_so2_state["longitude"].iloc[i]-1, c_so2_state["latitude"].iloc[i]-0.5, c_so2_state.state_code.iloc[i])

vmax = max(c_so2_state["total_SO2"])
print vmax
for i in range(c_so2_state.shape[0]):
    try:
        shape = world['United States'][state_to_shape[c_so2_state["state_code"].iloc[i]]]
    except:
        continue
    
    x = [p[0] for p in shape.points]
    y = [p[1] for p in shape.points]
    plt.fill(x,y, color=[1, 1-c_so2_state["total_SO2"].iloc[i]/vmax,1-c_so2_state["total_SO2"].iloc[i]/vmax])
    
plt.title("Heatmap of SO$_2$ concentration ($\mu g/m^3$) in 2012")
plt.xlabel("longitude")
plt.ylabel("latitude")
plt.axis([-130, -65, 23,50])
plt.savefig("../plots/heatmap_so2.png", dpi=200)
# Out:
# 557.2669

# %%
plt.figure(figsize=(15,10))
yr = 2012
c_so2_state = c_each_state.loc[c_each_state["year"] == yr]
for shape in world['United States']:
    x = [p[0] for p in shape.points]
    y = [p[1] for p in shape.points]
    plt.plot(x,y, c='k')


for i in range(c_so2_state.shape[0]):
    if c_so2_state.state_code.iloc[i] not in ["AK", "HI", "ON"]:
        plt.text(c_so2_state["longitude"].iloc[i]-1, c_so2_state["latitude"].iloc[i]-0.5, c_so2_state.state_code.iloc[i])

vmax = max(c_so2_state["total_NO3"])
print vmax
for i in range(c_so2_state.shape[0]):
    try:
        shape = world['United States'][state_to_shape[c_so2_state["state_code"].iloc[i]]]
    except:
        continue
    
    x = [p[0] for p in shape.points]
    y = [p[1] for p in shape.points]
    plt.fill(x,y, color=[1, 1-c_so2_state["total_NO3"].iloc[i]/vmax,1-c_so2_state["total_NO3"].iloc[i]/vmax])
    
plt.title("Heatmap of NO$_3$ concentration ($\mu g/m^3$) in 2012")
plt.xlabel("longitude")
plt.ylabel("latitude")
plt.axis([-130, -65, 23,50])
plt.savefig("../plots/heatmap_no3.png", dpi=200)
# Out:
# 514.9277
